# %% [markdown]
# <a href="https://colab.research.google.com/github/tsal4/data2000_labs/blob/main/labs/002_supply-stacks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Reordering Supply Stacks

# %% [markdown]
# ## Background

# %% [markdown]
# The expedition can depart as soon as the final supplies have been unloaded from the ships. Supplies are stored in stacks of marked crates, but because the needed supplies are buried under many other crates, the crates need to be rearranged.
#
# The ship has a giant cargo crane capable of moving crates between stacks. To ensure none of the crates get crushed or fall over, the crane operator will rearrange them in a series of carefully-planned steps. After the crates are rearranged, the desired crates will be at the top of each stack.
#
# The Elves don't want to interrupt the crane operator during this delicate procedure, but they forgot to ask her which crate will end up where, and they want to be ready to unload them as soon as possible so they can embark.
#
# They do, however, have a drawing of the starting stacks of crates and the rearrangement procedure (your puzzle input). For example:
#
# ```
#     [D]
# [N] [C]
# [Z] [M] [P]
#  1   2   3
#
# move 1 from 2 to 1
# move 3 from 1 to 3
# move 2 from 2 to 1
# move 1 from 1 to 2
# ```
#
# In this example, there are three stacks of crates. Stack 1 contains two crates: crate Z is on the bottom, and crate N is on top. Stack 2 contains three crates; from bottom to top, they are crates M, C, and D. Finally, stack 3 contains a single crate, P.
#
# Then, the rearrangement procedure is given. In each step of the procedure, a quantity of crates is moved from one stack to a different stack. In the first step of the above rearrangement procedure, one crate is moved from stack 2 to stack 1, resulting in this configuration:
#
# ```
# [D]
# [N] [C]
# [Z] [M] [P]
#  1   2   3
# ```
#
# In the second step, three crates are moved from stack 1 to stack 3. Crates are moved one at a time, so the first crate to be moved (D) ends up below the second and third crates:
#
# ```
#         [Z]
#         [N]
#     [C] [D]
#     [M] [P]
#  1   2   3
# ```
#
# Then, both crates are moved from stack 2 to stack 1. Again, because crates are moved one at a time, crate C ends up below crate M:
#
# ```
#         [Z]
#         [N]
# [M]     [D]
# [C]     [P]
#  1   2   3
# ```
#
# Finally, one crate is moved from stack 1 to stack 2:
#
# ```
#
#         [Z]
#         [N]
#         [D]
# [C] [M] [P]
#  1   2   3
# ```
#
# The Elves just need to know which crate will end up on top of each stack; in this example, the top crates are C in stack 1, M in stack 2, and Z in stack 3, so you should combine these together and give the Elves the message CMZ.
#
# After the rearrangement procedure completes, what crate ends up on top of each stack?

# %% [markdown]
# ## Solution

# %% [markdown]
# First, let's just load in our data and see what we're working with:

# %%
# We will start by reading in the file, one line at a time, using the
# readlines() method. As a reminder, the
#
#   with open('filename', 'r') as f
#
# line is called a context manager in Python: in this case, it's an
# easy way to handle a lot of the nitty gritty of opening / reading /closing
# files.
with open('/content/lab-002_supply-stacks.txt', 'r') as f:
    data = [line.strip() for line in f.readlines()]

for line in data[:15]:
    print(line)
# Out:
# [N] [G]                     [Q]
# [H] [B]         [B] [R]     [H]
# [S] [N]     [Q] [M] [T]     [Z]
# [J] [T]     [R] [V] [H]     [R] [S]
# [F] [Q]     [W] [T] [V] [J] [V] [M]
# [W] [P] [V] [S] [F] [B] [Q] [J] [H]
# [T] [R] [Q] [B] [D] [D] [B] [N] [N]
# [D] [H] [L] [N] [N] [M] [D] [D] [B]
# 1   2   3   4   5   6   7   8   9
#
# move 3 from 1 to 2
# move 1 from 7 to 1
# move 1 from 6 to 5
# move 5 from 5 to 9
# move 2 from 5 to 2

# %% [markdown]
# Since this is all just raw text strings, let's start by splitting the list of strings on the first empty line that we see. Looking through the input file, we can note that each line is one of 3 cases:
#
#   1. The line contains information about the crates
#   2. The line contains information about the crate movement instructions
#   3. The line is blank
#
#   Given this, we know that we can just find the index position of the blank line and split our list into respective "crate stacks" and "instructions" lists

# %%
split_pos = data.index("")

# list slicing
# variable[start_position (inclusive) : end_position (exclusive)]
stacks = data[:split_pos]
instructions = data[split_pos + 1:]

# %%
stacks
# Out:
# ['[N] [G]                     [Q]',
#  '[H] [B]         [B] [R]     [H]',
#  '[S] [N]     [Q] [M] [T]     [Z]',
#  '[J] [T]     [R] [V] [H]     [R] [S]',
#  '[F] [Q]     [W] [T] [V] [J] [V] [M]',
#  '[W] [P] [V] [S] [F] [B] [Q] [J] [H]',
#  '[T] [R] [Q] [B] [D] [D] [B] [N] [N]',
#  '[D] [H] [L] [N] [N] [M] [D] [D] [B]',
#  '1   2   3   4   5   6   7   8   9']

# %% [markdown]
# Now we need to figure out how many stacks of crates there are. Since any individual row of crates in our `stacks` list can have blanks, we need to look at the bottom-most row of data which contains the column number of each stack.
#
# We'll use the `list[-1]` syntax to grab that last element of the list, and then split on whitespace so that we're just left with the number parts of the line. Lastly, we really only care about the final number in the sequence since that gives us the total number of stacks, so we'll again use that `list[-1]` syntax to just extract (in this case) the number `9`:

# %%
num_stacks = int(stacks[-1].split()[-1])
num_stacks
# Out:
# 9

# %% [markdown]
# Since we know how many stacks of crates we now need, let's initialize an empty list of lists to represent each of the stacks in that range:

# %%
stacks_list = [[] for _ in range(num_stacks)]
stacks_list
# Out:
# [[], [], [], [], [], [], [], [], []]

# %% [markdown]
# ## Parsing the stacks
#
# Our basic data structure is looking solid, so now we need to parse the actual crates and figure out which crate belongs in which stack, and how high or low it is in the stack.
#
# To do this, we can capitalize on the fact that our data are regular and have a repeating pattern. All rows of crates follow the same pattern:
#
#   - `[`
#   - Crate name (a capital letter)
#   - `]`
#   - ` ` (a blank space)
#
# and this pattern repeats across the line. Since we know that every 4th character in each row can be a crate name, we can skip over every index that's not a multiple of 4 and just ignore that information as extraneous. To figure out whether there actually is or isn't a crate in each spot, we can use the `str.isalpha()` function to check whether the character looks like a letter in the range `[a-zA-Z]`:

# %%
for line_idx, line in enumerate(stacks[:-1][::-1]):
    print(f"Line {line_idx}:")
    print(f"\t{line}")
    print(f"\t{[
        (char, (char_idx // 4))
        for char_idx, char in enumerate(line)
        if char.isalpha()
    ]}")

    for char_idx, char in enumerate(line):
        if char.isalpha():
            stacks_list[char_idx // 4].append(char)
# Out:
# Line 0:
# 	[D] [H] [L] [N] [N] [M] [D] [D] [B]
# 	[('D', 0), ('H', 1), ('L', 2), ('N', 3), ('N', 4), ('M', 5), ('D', 6), ('D', 7), ('B', 8)]
# Line 1:
# 	[T] [R] [Q] [B] [D] [D] [B] [N] [N]
# 	[('T', 0), ('R', 1), ('Q', 2), ('B', 3), ('D', 4), ('D', 5), ('B', 6), ('N', 7), ('N', 8)]
# Line 2:
# 	[W] [P] [V] [S] [F] [B] [Q] [J] [H]
# 	[('W', 0), ('P', 1), ('V', 2), ('S', 3), ('F', 4), ('B', 5), ('Q', 6), ('J', 7), ('H', 8)]
# Line 3:
# 	[F] [Q]     [W] [T] [V] [J] [V] [M]
# 	[('F', 0), ('Q', 1), ('W', 3), ('T', 4), ('V', 5), ('J', 6), ('V', 7), ('M', 8)]
# Line 4:
# 	[J] [T]     [R] [V] [H]     [R] [S]
# 	[('J', 0), ('T', 1), ('R', 3), ('V', 4), ('H', 5), ('R', 7), ('S', 8)]
# Line 5:
# 	[S] [N]     [Q] [M] [T]     [Z]
# 	[('S', 0), ('N', 1), ('Q', 3), ('M', 4), ('T', 5), ('Z', 7)]
# Line 6:
# 	[H] [B]         [B] [R]     [H]
# 	[('H', 0), ('B', 1), ('B', 4), ('R', 5), ('H', 7)]
# Line 7:
# 	[N] [G]                     [Q]
# 	[('N', 0), ('G', 1), ('Q', 7)]

# %% [markdown]
# This gives us just the letter names of the crates in each stack, each in a nested list corresponding to its stack. Note that we've effectively rotated the set of stacks 90 degrees: stacks expand to the right instead of upwards.
#
# By doing this, we're able to take advantage of Python list slicing syntax, rather than having to implement extra parsing logic to maintain the vertical stack orientation

# %%
stacks_list
# Out:
# [['D', 'T', 'W', 'F', 'J', 'S', 'H', 'N'],
#  ['H', 'R', 'P', 'Q', 'T', 'N', 'B', 'G'],
#  ['L', 'Q', 'V'],
#  ['N', 'B', 'S', 'W', 'R', 'Q'],
#  ['N', 'D', 'F', 'T', 'V', 'M', 'B'],
#  ['M', 'D', 'B', 'V', 'H', 'T', 'R'],
#  ['D', 'B', 'Q', 'J'],
#  ['D', 'N', 'J', 'V', 'R', 'Z', 'H', 'Q'],
#  ['B', 'N', 'H', 'M', 'S']]

# %% [markdown]
# ## Parsing the instructions

# %%
instructions[0]
# Out:
# 'move 3 from 1 to 2'

# %% [markdown]
# We know that there are 3 relevant pieces of information contained in each instruction: the number of crates to move; the stack to move them from; and the stack to move them to.
#
# Given that these will always be numeric, we can take a similar approach as we did using the `.isalpha()` function previously: in this case, we will use the `.isdigit()` function to identify whether any word in each line of instructions is numeric or not.
#
# Note that we also use the `.split()` function to break each line up into individual words whenever we see a whitespace. We do this because a list comprehension on the raw string --- e.g.,
#
# ```
# [int(char) for char in instructions[0] if char.isdigit()]
# ```
# would operate character-wise. That is, for the first instruction, `move 3 from 1 to 2`, it would look character-by-character: `m`, `o`, `v`, `e`, ` `, `3`, and so on.
#
# Although this works for the first line of instructions, as soon as we hit an instruction that asks us to move 10 or more crates at a time, our parsing will break

# %%
parsed_instructions = [
    [int(char) for char in line.split() if char.isdigit()]
    for line in instructions
]
parsed_instructions[0]
# Out:
# [3, 1, 2]

# %% [markdown]
# ## Moving the crates
#
# Now that we have parsed both our list of crates and the corresponding instructions, actually moving the crates around becomes pretty straightforward. To do this, we simply make a for loop to iterate through each instruction in order, and for each instruction:
#
# - Figure out how many crates need to be moved
# - For each crate that should be moved
# - Remove it from the original stack with the `.pop()` method
# - Add it to the destinatio stack with the `.append()` method
#
# I also print out the stacks after each iteration for the first couple of instructions, just to verify that our code is behaving as we expect it to.

# %%
for instruction_idx, instruction in enumerate(parsed_instructions):
    if instruction_idx < 2:
        print(instructions[instruction_idx])
    crates_to_move = instruction[0]
    from_stack = instruction[1] - 1
    end_stack = instruction[2] - 1

    for crate_idx in range(crates_to_move):
        moving_crate = stacks_list[from_stack].pop()
        stacks_list[end_stack].append(moving_crate)

        if instruction_idx < 2:
            print(f"State after instruction {instruction_idx}, crate {crate_idx} of {crates_to_move}")
            for stack in stacks_list:
                print(f"\t{stack}")
# Out:
# move 3 from 1 to 2
# State after instruction 0, crate 0 of 3
# 	['D', 'T', 'W', 'F', 'J', 'S', 'H']
# 	['H', 'R', 'P', 'Q', 'T', 'N', 'B', 'G', 'N']
# 	['L', 'Q', 'V']
# 	['N', 'B', 'S', 'W', 'R', 'Q']
# 	['N', 'D', 'F', 'T', 'V', 'M', 'B']
# 	['M', 'D', 'B', 'V', 'H', 'T', 'R']
# 	['D', 'B', 'Q', 'J']
# 	['D', 'N', 'J', 'V', 'R', 'Z', 'H', 'Q']
# 	['B', 'N', 'H', 'M', 'S']
# State after instruction 0, crate 1 of 3
# 	['D', 'T', 'W', 'F', 'J', 'S']
# 	['H', 'R', 'P', 'Q', 'T', 'N', 'B', 'G', 'N', 'H']
# 	['L', 'Q', 'V']
# 	['N', 'B', 'S', 'W', 'R', 'Q']
# 	['N', 'D', 'F', 'T', 'V', 'M', 'B']
# 	['M', 'D', 'B', 'V', 'H', 'T', 'R']
# 	['D', 'B', 'Q', 'J']
# 	['D', 'N', 'J', 'V', 'R', 'Z', 'H', 'Q']
# 	['B', 'N', 'H', 'M', 'S']
# State after instruction 0, crate 2 of 3
# 	['D', 'T', 'W', 'F', 'J']
# 	['H', 'R', 'P', 'Q', 'T', 'N', 'B', 'G', 'N', 'H', 'S']
# 	['L', 'Q', 'V']
# 	['N', 'B', 'S', 'W', 'R', 'Q']
# 	['N', 'D', 'F', 'T', 'V', 'M', 'B']
# 	['M', 'D', 'B', 'V', 'H', 'T', 'R']
# ...

# %% [markdown]
# After iterating through all of the instructions in our input, the final arrangement of crates looks like:

# %%
stacks_list
# Out:
# [['G'],
#  ['R'],
#  ['V', 'S', 'T', 'T'],
#  ['D', 'N', 'R', 'W', 'S'],
#  ['F', 'V', 'B', 'T', 'B', 'J', 'D', 'M', 'W'],
#  ['Q', 'D', 'B', 'Q', 'P', 'Q', 'F', 'M', 'V', 'N'],
#  ['N', 'J'],
#  ['J', 'B', 'N', 'T', 'L', 'H', 'M', 'D', 'R', 'D', 'H', 'N', 'H'],
#  ['N', 'V', 'Q', 'R', 'S', 'B', 'B', 'Z', 'H', 'Q', 'H']]

# %% [markdown]
# Finally, to solve the problem, we need to figure out what crate is on top of each stack. We use the `[-1]` list slicing syntax to grab only the last element of each stack (i.e., the top-most crate) and print out the concatenated result as a string:

# %%
''.join([stack[-1] for stack in stacks_list])
# Out:
# 'GRTSWNJHH'

# %% [markdown]
# # Part Two

# %% [markdown]
# As you watch the crane operator expertly rearrange the crates, you notice the process isn't following your prediction.
#
# Some mud was covering the writing on the side of the crane, and you quickly wipe it away. The crane isn't a CrateMover 9000 - it's a CrateMover 9001.
#
# The CrateMover 9001 is notable for many new and exciting features: air conditioning, leather seats, an extra cup holder, and the ability to pick up and move multiple crates at once.
#
# Again considering the example above, the crates begin in the same configuration:
#
# ```
#     [D]
# [N] [C]
# [Z] [M] [P]
#  1   2   3
#
# move 1 from 2 to 1
# move 3 from 1 to 3
# move 2 from 2 to 1
# move 1 from 1 to 2
# ```

# %% [markdown]
# Moving a single crate from stack 2 to stack 1 behaves the same as before:
#
# ```
# [D]
# [N] [C]
# [Z] [M] [P]
#  1   2   3
# ```
#
# However, the action of moving three crates from stack 1 to stack 3 means that those three moved crates stay in the same order, resulting in this new configuration:
#
# ```
#         [D]
#         [N]
#     [C] [Z]
#     [M] [P]
#  1   2   3
# ```
#
# Next, as both crates are moved from stack 2 to stack 1, they retain their order as well:
#
# ```
#         [D]
#         [N]
# [C]     [Z]
# [M]     [P]
#  1   2   3
# ```
#
# Finally, a single crate is still moved from stack 1 to stack 2, but now it's crate C that gets moved:
#
# ```
#         [D]
#         [N]
#         [Z]
# [M] [C] [P]
#  1   2   3
# ```
#
# In this example, the CrateMover 9001 has put the crates in a totally different order: MCD.
#
# Before the rearrangement process finishes, update your simulation so that the Elves know where they should stand to be ready to unload the final supplies. After the rearrangement procedure completes, what crate ends up on top of each stack?

# %%
with open('/content/lab-002_supply-stacks.txt', 'r') as f:
  data2 = [line.strip() for line in f.readlines()]

for line in data2[:15]:
    print(line)
# Out:
# [N] [G]                     [Q]
# [H] [B]         [B] [R]     [H]
# [S] [N]     [Q] [M] [T]     [Z]
# [J] [T]     [R] [V] [H]     [R] [S]
# [F] [Q]     [W] [T] [V] [J] [V] [M]
# [W] [P] [V] [S] [F] [B] [Q] [J] [H]
# [T] [R] [Q] [B] [D] [D] [B] [N] [N]
# [D] [H] [L] [N] [N] [M] [D] [D] [B]
# 1   2   3   4   5   6   7   8   9
#
# move 3 from 1 to 2
# move 1 from 7 to 1
# move 1 from 6 to 5
# move 5 from 5 to 9
# move 2 from 5 to 2

# %%
split_pos2 = data2.index("")

# list slicing
# variable[start_position (inclusive) : end_position (exclusive)]
stacks2 = data2[:split_pos2]
instructions2 = data2[split_pos2 + 1:]

stacks
# Out:
# ['[N] [G]                     [Q]',
#  '[H] [B]         [B] [R]     [H]',
#  '[S] [N]     [Q] [M] [T]     [Z]',
#  '[J] [T]     [R] [V] [H]     [R] [S]',
#  '[F] [Q]     [W] [T] [V] [J] [V] [M]',
#  '[W] [P] [V] [S] [F] [B] [Q] [J] [H]',
#  '[T] [R] [Q] [B] [D] [D] [B] [N] [N]',
#  '[D] [H] [L] [N] [N] [M] [D] [D] [B]',
#  '1   2   3   4   5   6   7   8   9']

# %%
num_stacks2 = int(stacks2[-1].split()[-1])
num_stacks2
# Out:
# 9

# %%
stacks_list2 = [[] for _ in range(num_stacks2)]
stacks_list2
# Out:
# [[], [], [], [], [], [], [], [], []]

# %%
for line_idx, line in enumerate(stacks2[:-1][::-1]):
    print(f"Line {line_idx}:")
    print(f"\t{line}")
    print(f"\t{[
        (char, (char_idx // 4))
        for char_idx, char in enumerate(line)
        if char.isalpha()
    ]}")

    for char_idx, char in enumerate(line):
        if char.isalpha():
            stacks_list2[char_idx // 4].append(char)
# Out:
# Line 0:
# 	[D] [H] [L] [N] [N] [M] [D] [D] [B]
# 	[('D', 0), ('H', 1), ('L', 2), ('N', 3), ('N', 4), ('M', 5), ('D', 6), ('D', 7), ('B', 8)]
# Line 1:
# 	[T] [R] [Q] [B] [D] [D] [B] [N] [N]
# 	[('T', 0), ('R', 1), ('Q', 2), ('B', 3), ('D', 4), ('D', 5), ('B', 6), ('N', 7), ('N', 8)]
# Line 2:
# 	[W] [P] [V] [S] [F] [B] [Q] [J] [H]
# 	[('W', 0), ('P', 1), ('V', 2), ('S', 3), ('F', 4), ('B', 5), ('Q', 6), ('J', 7), ('H', 8)]
# Line 3:
# 	[F] [Q]     [W] [T] [V] [J] [V] [M]
# 	[('F', 0), ('Q', 1), ('W', 3), ('T', 4), ('V', 5), ('J', 6), ('V', 7), ('M', 8)]
# Line 4:
# 	[J] [T]     [R] [V] [H]     [R] [S]
# 	[('J', 0), ('T', 1), ('R', 3), ('V', 4), ('H', 5), ('R', 7), ('S', 8)]
# Line 5:
# 	[S] [N]     [Q] [M] [T]     [Z]
# 	[('S', 0), ('N', 1), ('Q', 3), ('M', 4), ('T', 5), ('Z', 7)]
# Line 6:
# 	[H] [B]         [B] [R]     [H]
# 	[('H', 0), ('B', 1), ('B', 4), ('R', 5), ('H', 7)]
# Line 7:
# 	[N] [G]                     [Q]
# 	[('N', 0), ('G', 1), ('Q', 7)]

# %%
stacks_list2
# Out:
# [['D', 'T', 'W', 'F', 'J', 'S', 'H', 'N'],
#  ['H', 'R', 'P', 'Q', 'T', 'N', 'B', 'G'],
#  ['L', 'Q', 'V'],
#  ['N', 'B', 'S', 'W', 'R', 'Q'],
#  ['N', 'D', 'F', 'T', 'V', 'M', 'B'],
#  ['M', 'D', 'B', 'V', 'H', 'T', 'R'],
#  ['D', 'B', 'Q', 'J'],
#  ['D', 'N', 'J', 'V', 'R', 'Z', 'H', 'Q'],
#  ['B', 'N', 'H', 'M', 'S']]

# %%
instructions2[:5]
# Out:
# ['move 3 from 1 to 2',
#  'move 1 from 7 to 1',
#  'move 1 from 6 to 5',
#  'move 5 from 5 to 9',
#  'move 2 from 5 to 2']

# %%
parsed_instructions2 = [
    [int(char) for char in line.split() if char.isdigit()]
    for line in instructions2
]
parsed_instructions2[:5]
# Out:
# [[3, 1, 2], [1, 7, 1], [1, 6, 5], [5, 5, 9], [2, 5, 2]]

# %%
# make auxiliary list for all crates being moved over
# add slice to this aux list
# .extend() aux list to new stack

for instruction_idx, instruction in enumerate(parsed_instructions):
  crates_to_move = instruction[0]
  from_idx = instruction[1] - 1
  to_idx = instruction[2] - 1
  from_stack = stacks_list2[from_idx]
  moving_stack = []

  moving_stack = from_stack[-crates_to_move:] #grabs crates that need to be moved using list slicing
  stacks_list2[from_idx] = from_stack[:-crates_to_move] #actually removes the moving crates from the stack
  stacks_list2[to_idx].extend(moving_stack) #places the moving crates onto the "top" of the destination stack

# %%
stacks_list2
# Out:
# [['Q'],
#  ['L'],
#  ['M', 'H', 'R', 'F'],
#  ['S', 'T', 'M', 'J', 'Q'],
#  ['D', 'S', 'Q', 'N', 'V', 'T', 'H', 'W', 'D'],
#  ['D', 'J', 'N', 'R', 'H', 'B', 'B', 'F', 'T', 'B'],
#  ['N', 'B'],
#  ['J', 'P', 'Q', 'Q', 'N', 'S', 'W', 'R', 'V', 'V', 'T', 'D', 'H'],
#  ['R', 'V', 'G', 'D', 'B', 'Z', 'H', 'N', 'N', 'B', 'M']]

# %%
''.join([stack[-1] for stack in stacks_list2])
# Out:
# 'QLFQDBBHM'
